# %% [markdown]
# Pandas is a Python library used for working with data sets.
#
# The name "Pandas" has a reference to both "**Panel Data**", and "**Python Data Analysis**" and was created by Wes McKinney in 2008.

# %%
#pandas installation
# !pip install pandas

# %%
#importing pandas
import pandas

# %%
#Example
import pandas

mydataset = {
  'cars': ["BMW", "Volvo", "Ford"],
  'passings': [3, 7, 2]
}

myvar = pandas.DataFrame(mydataset)

print(myvar)
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2

# %% [markdown]
# A Pandas DataFrame is a 2 dimensional data structure, like a 2 dimensional array, or a table with rows and columns.

# %%
#Data Frame
import pandas as pd

data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

#load data into a DataFrame object:
df = pd.DataFrame(data)

print(df)
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
#Pandas use the loc attribute to return one or more specified row(s)
#refer to the row index:
print(df.loc[0])
# Out:
# calories    420
# duration     50
# Name: 0, dtype: int64

# %%
#use a list of indexes:
print(df.loc[[0, 1]])
# Out:
#    calories  duration
# 0       420        50
# 1       380        40

# %% [markdown]
# # **Read csv files**

# %%
#Read CSV files
#df = pd.read_csv('Filename.csv')

# %% [markdown]
# # **Read JSON**
# Big data sets are often stored, or extracted as JSON.
#
# JSON is plain text, but has the format of an object, and is well known in the world of programming, including Pandas.

# %%
#df = pd.read_json('data.json')

# %% [markdown]
# # **Viewing the data**
# The head() method returns the headers and a specified number of rows, starting from the top.
#
# The tail() method returns the headers and a specified number of rows, starting from the bottom.
#
# The describe() method in Pandas generates descriptive statistics of DataFrame columns which provides key metrics like mean, standard deviation, percentiles.

# %%
#df = pd.read_csv('data.csv')

#print(df.head())

# %%
#print(df.tail())

# %%
#print(df.describe())

# %% [markdown]
# # **Data Visualization**
#
# Pandas uses the plot() method to plot.

# %% [markdown]
# **Line Plot**

# %%
import matplotlib.pyplot as plt

df = pd.read_csv('data.csv')
df.plot()
plt.show()

# %% [markdown]
# **Scatter Plot**

# %%
df = pd.read_csv('data.csv')

df.plot(kind = 'scatter', x = 'Duration', y = 'Calories')

plt.show()

# %% [markdown]
# **Area Plots**

# %%
df.plot.area(alpha=0.4)
#alpha=0.4 sets transparency to make overlaps clearer.

# %% [markdown]
# **Bar Plots**

# %%
df.plot.bar()

# %% [markdown]
# **Histogram Plots**

# %%
#df[column].plot.hist(bins=pandas.value_counts)
#bins sets the number of bins to show the data distribution more clearly.

# %% [markdown]
# **Box Plots**

# %%
df.plot.box()

# %% [markdown]
# **Pie Chart**

# %%
#df['column'].value_counts().plot(kind='pie')

# %% [markdown]
# **Saving plot**

# %%
#plt.savefig("plot.png")

# %% [markdown]
# https://pandas.pydata.org/
# https://www.geeksforgeeks.org/pandas
# https://www.w3schools.com/python/pandas
