# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense
from tensorflow.keras.datasets import mnist

# %%
#Load and Prepare Data
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize pixel values to 0–1
x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
# Define the Sequential model
model = Sequential([
    # Flatten: Converts each 28x28 image into a 1D vector of length 784
    Flatten(input_shape=(28, 28)),

    # Dense hidden layer with 128 neurons and ReLU activation
    Dense(128, activation='relu'),

    # Output layer with 10 neurons (one for each digit 0–9) and softmax activation
    Dense(10, activation='softmax')
])

# %%
#Compile the Model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
#Train the Model
model.fit(x_train, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8756 - loss: 0.4391
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9657 - loss: 0.1171
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9776 - loss: 0.0740
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9830 - loss: 0.0555
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9878 - loss: 0.0426

# %%
#Evaluate on Unseen Data
test_loss, test_acc = model.evaluate(x_test, y_test)
print("Test accuracy:", test_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9735 - loss: 0.0903
# Test accuracy: 0.9768999814987183

# %%
#Predict Individual Samples
predictions = model.predict(x_test)
print("Model predicted:", predictions[0].argmax())
print("Actual value:", y_test[0])
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Model predicted: 7
# Actual value: 7
